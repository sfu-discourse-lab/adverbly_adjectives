# %%
import numpy as np
import pandas as pd
import itertools
import os, re
from collections import defaultdict

# %%
def makeDirs(dirs):
    curr_path = '.'
    for d in dirs:
        os.makedirs(curr_path+'/'+d, exist_ok=True)
        curr_path = curr_path+'/'+d

# %%
def getHapax(filepath):
    split = filepath.split('/')
    fname = split[-1]
    dir_structure = ['hapax_legomena']
    dir_structure += split[1:-1]
    makeDirs(dir_structure)
    hapax_path = '/'.join(dir_structure) + '/' + fname
    print(hapax_path)
    
    df = pd.read_csv(filepath)
    df[df['counts'] == 1].to_csv(hapax_path)

# %%
basepath = 'adverbly_adjectives'
files = []
for corpus in os.listdir(basepath):
    for f_or_d in os.listdir(basepath+'/'+corpus):
        if os.path.isdir(basepath+'/'+corpus+'/'+f_or_d):
            genres_list = [basepath+'/'+corpus+'/'+f_or_d+'/'+f for f in os.listdir(basepath+'/'+corpus+'/'+f_or_d)]
            files += genres_list
        else:
            assert os.path.isfile(basepath+'/'+corpus+'/'+f_or_d)
            file = [basepath+'/'+corpus+'/'+f_or_d]
            files += file
            
for f in files:
#     print(f)
    getHapax(f)
# Out:
# hapax_legomena/Cornell/all_pairs.csv
# hapax_legomena/Movies/all_pairs.csv
# hapax_legomena/sfu_review/genres/HOTELS_pairs.csv
# hapax_legomena/sfu_review/genres/MOVIES_pairs.csv
# hapax_legomena/sfu_review/genres/BOOKS_pairs.csv
# hapax_legomena/sfu_review/genres/COOKWARE_pairs.csv
# hapax_legomena/sfu_review/genres/PHONES_pairs.csv
# hapax_legomena/sfu_review/genres/CARS_pairs.csv
# hapax_legomena/sfu_review/genres/COMPUTERS_pairs.csv
# hapax_legomena/sfu_review/genres/MUSIC_pairs.csv
# hapax_legomena/sfu_review/all_pairs.csv
# hapax_legomena/COCA/genres/Magazine_pairs.csv
# hapax_legomena/COCA/genres/Academic_pairs.csv
# hapax_legomena/COCA/genres/Fiction_pairs.csv
# hapax_legomena/COCA/genres/News_pairs.csv
# hapax_legomena/COCA/genres/Spoken_pairs.csv
# hapax_legomena/COCA/all_pairs.csv
# hapax_legomena/NYT/decades/1927_pairs.csv
# hapax_legomena/NYT/decades/1928_pairs.csv
# hapax_legomena/NYT/decades/1997_pairs.csv
# hapax_legomena/NYT/decades/2010_pairs.csv
# hapax_legomena/NYT/decades/1965_pairs.csv
# hapax_legomena/NYT/decades/1942_pairs.csv
# hapax_legomena/NYT/decades/1976_pairs.csv
# hapax_legomena/NYT/decades/1989_pairs.csv
# hapax_legomena/NYT/decades/1993_pairs.csv
# hapax_legomena/NYT/decades/2012_pairs.csv
# hapax_legomena/NYT/decades/1933_pairs.csv
# hapax_legomena/NYT/decades/1957_pairs.csv
# hapax_legomena/NYT/decades/1931_pairs.csv
# hapax_legomena/NYT/decades/1987_pairs.csv
# hapax_legomena/NYT/decades/1979_pairs.csv
# hapax_legomena/NYT/decades/2001_pairs.csv
# hapax_legomena/NYT/decades/1958_pairs.csv
# hapax_legomena/NYT/decades/1983_pairs.csv
# hapax_legomena/NYT/decades/2013_pairs.csv
# hapax_legomena/NYT/decades/1975_pairs.csv
# hapax_legomena/NYT/decades/1951_pairs.csv
# hapax_legomena/NYT/decades/1956_pairs.csv
# hapax_legomena/NYT/decades/2017_pairs.csv
# hapax_legomena/NYT/decades/1960_pairs.csv
# hapax_legomena/NYT/decades/1930_pairs.csv
# hapax_legomena/NYT/decades/1977_pairs.csv
# hapax_legomena/NYT/decades/2006_pairs.csv
# hapax_legomena/NYT/decades/1996_pairs.csv
# hapax_legomena/NYT/decades/1910_pairs.csv
# hapax_legomena/NYT/decades/2000_pairs.csv
# hapax_legomena/NYT/decades/2008_pairs.csv
# hapax_legomena/NYT/decades/1915_pairs.csv
# hapax_legomena/NYT/decades/2004_pairs.csv
# hapax_legomena/NYT/decades/1964_pairs.csv
# hapax_legomena/NYT/decades/1962_pairs.csv
# hapax_legomena/NYT/decades/1995_pairs.csv
# hapax_legomena/NYT/decades/1921_pairs.csv
# hapax_legomena/NYT/decades/1978_pairs.csv
# hapax_legomena/NYT/decades/1974_pairs.csv
# hapax_legomena/NYT/decades/2009_pairs.csv
# hapax_legomena/NYT/decades/1946_pairs.csv
# hapax_legomena/NYT/decades/1926_pairs.csv
# hapax_legomena/NYT/decades/1935_pairs.csv
# hapax_legomena/NYT/decades/1939_pairs.csv
# hapax_legomena/NYT/decades/1968_pairs.csv
# hapax_legomena/NYT/decades/1953_pairs.csv
# hapax_legomena/NYT/decades/1966_pairs.csv
# hapax_legomena/NYT/decades/1961_pairs.csv
# hapax_legomena/NYT/decades/1949_pairs.csv
# hapax_legomena/NYT/decades/1943_pairs.csv
# hapax_legomena/NYT/decades/2005_pairs.csv
# hapax_legomena/NYT/decades/1923_pairs.csv
# hapax_legomena/NYT/decades/1959_pairs.csv
# hapax_legomena/NYT/decades/1955_pairs.csv
# hapax_legomena/NYT/decades/1982_pairs.csv
# hapax_legomena/NYT/decades/1925_pairs.csv
# hapax_legomena/NYT/decades/1973_pairs.csv
# hapax_legomena/NYT/decades/1950_pairs.csv
# hapax_legomena/NYT/decades/1924_pairs.csv
# hapax_legomena/NYT/decades/2002_pairs.csv
# hapax_legomena/NYT/decades/1929_pairs.csv
# hapax_legomena/NYT/decades/1969_pairs.csv
# hapax_legomena/NYT/decades/1988_pairs.csv
# hapax_legomena/NYT/decades/1984_pairs.csv
# hapax_legomena/NYT/decades/1990_pairs.csv
# hapax_legomena/NYT/decades/1992_pairs.csv
# hapax_legomena/NYT/decades/2011_pairs.csv
# hapax_legomena/NYT/decades/1954_pairs.csv
# hapax_legomena/NYT/decades/1916_pairs.csv
# hapax_legomena/NYT/decades/1999_pairs.csv
# hapax_legomena/NYT/decades/2019_pairs.csv
# hapax_legomena/NYT/decades/1952_pairs.csv
# hapax_legomena/NYT/decades/1941_pairs.csv
# hapax_legomena/NYT/decades/2015_pairs.csv
# hapax_legomena/NYT/decades/1937_pairs.csv
# hapax_legomena/NYT/decades/2018_pairs.csv
# hapax_legomena/NYT/decades/1940_pairs.csv
# hapax_legomena/NYT/decades/2016_pairs.csv
# hapax_legomena/NYT/decades/1967_pairs.csv
# hapax_legomena/NYT/decades/1920_pairs.csv
# hapax_legomena/NYT/decades/1980_pairs.csv
# hapax_legomena/NYT/decades/1944_pairs.csv
# hapax_legomena/NYT/decades/1981_pairs.csv
# hapax_legomena/NYT/decades/1998_pairs.csv
# hapax_legomena/NYT/decades/1936_pairs.csv
# hapax_legomena/NYT/decades/1972_pairs.csv
# hapax_legomena/NYT/decades/1985_pairs.csv
# hapax_legomena/NYT/decades/1934_pairs.csv
# hapax_legomena/NYT/decades/1994_pairs.csv
# hapax_legomena/NYT/decades/1970_pairs.csv
# hapax_legomena/NYT/decades/1971_pairs.csv
# hapax_legomena/NYT/decades/1986_pairs.csv
# hapax_legomena/NYT/decades/2014_pairs.csv
# hapax_legomena/NYT/decades/1948_pairs.csv
# hapax_legomena/NYT/decades/1932_pairs.csv
# hapax_legomena/NYT/decades/2007_pairs.csv
# hapax_legomena/NYT/decades/1938_pairs.csv
# hapax_legomena/NYT/decades/2003_pairs.csv
# hapax_legomena/NYT/decades/1963_pairs.csv
# hapax_legomena/NYT/decades/1991_pairs.csv
# hapax_legomena/NYT/decades/1947_pairs.csv
# hapax_legomena/NYT/decades/1945_pairs.csv
# hapax_legomena/NYT/all_pairs.csv
# hapax_legomena/SOCC/all_pairs.csv
# hapax_legomena/CORE/genres/Interactive_Discussion_pairs.csv
# hapax_legomena/CORE/genres/Information_Persuasion_pairs.csv
# hapax_legomena/CORE/genres/Narrative_pairs.csv
# hapax_legomena/CORE/genres/Opinion_pairs.csv
# hapax_legomena/CORE/genres/Lyrical_pairs.csv
# hapax_legomena/CORE/genres/Information_Description_pairs.csv
# hapax_legomena/CORE/genres/How-to__Instructional_pairs.csv
# hapax_legomena/CORE/genres/Spoken_pairs.csv
# hapax_legomena/CORE/all_pairs.csv
