# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import itertools
import os, re, csv
sns.set()
sns.set_context('talk')
colours = itertools.cycle(sns.color_palette('Set2'))
palettes = itertools.cycle([sns.color_palette('PuBuGn_d'), sns.color_palette('Oranges_d'), sns.color_palette('GnBu_d'), sns.color_palette('Reds_d'), sns.color_palette('Blues_d'), sns.color_palette('PuRd_d')])
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = [8.0, 6.0]
plt.rcParams.update({'figure.autolayout': False})

# %%
# with open('oxymorons/oxymorons_coca.csv')

# %%
df = pd.read_csv('oxymorons/oxymorons_coca.csv')

# %%
df[['pair', 'diff']]
# Out:
#                            pair   diff
# 0           indirectly curative  1.625
# 1             amusingly hapless  1.625
# 2         imposingly villainous  1.528
# 3           intrinsically messy  1.500
# 4      affectionately querulous  1.500
# 5              doubly troubling  1.500
# 6            doubly troublesome  1.500
# 7         impressively agonized  1.500
# 8      unfortunately successful  1.500
# 9           regrettably genteel  1.500
# 10            comically hapless  1.500
# 11      woefully indiscriminate  1.500
# 12      thoroughly disingenuous  1.500
# 13           impressively scary  1.500
# 14           impressively stoic  1.500
# 15            doubly disturbing  1.500
# 16     thoroughly untraditional  1.500
# 17        deceptively childlike  1.500
# 18     intrinsically censorious  1.500
# 19       unfortunately catholic  1.500
# 20      thoroughly otherworldly  1.500
# 21           genuinely worrying  1.500
# 22         genuinely disturbing  1.500
# 23     thoroughly reprehensible  1.500
# 24     genuinely transcendental  1.500
# 25          comically nefarious  1.403
# 26         comically villainous  1.403
# 27          genuinely nefarious  1.403
# 28      manifestly insufficient  1.375
# 29          doubly excruciating  1.375
# ...                         ...    ...
# 67614     uncomfortably cloying  0.000
# 67615          fully convincing  0.000
# 67616         wholly reassuring  0.000
# 67617    uncomfortably childish  0.000
# 67618       unbelievably serene  0.000
# 67619           fully developed  0.000
# 67620         cleverly foldable  0.000
# 67621       fully determinative  0.000
# 67622         cleverly humorous  0.000
# 67623          wholly separable  0.000
# 67624        hopelessly knotted  0.000
# 67625   genuinely compassionate  0.000
# 67626    unbelievably strenuous  0.000
# 67627         hopelessly infirm  0.000
# 67628   genuinely controversial  0.000
# 67629      unbelievably tedious  0.000
# 67630           fully decorated  0.000
# 67631         clinically benign  0.000
# 67632            fully dazzling  0.000
# 67633      unbelievably trivial  0.000
# 67634     apparently convincing  0.000
# 67635      unbelievably wealthy  0.000
# 67636       clinically focussed  0.000
# 67637          clinically inane  0.000
# 67638    clinically interesting  0.000
# 67639     apparently consenting  0.000
# 67640            fully creative  0.000
# 67641    uncomfortably bareback  0.000
# 67642     apparently comparable  0.000
# 67643         totally equitable  0.000
#
# [67644 rows x 2 columns]

# %%
df[(df['diff'] > 0.4) & (df['diff'] < 0.5)][['pair', 'diff']]
# Out:
#                           pair      diff
# 26126            morally rough  0.499834
# 26127               really dim  0.499792
# 26128    unquestionably deadly  0.499583
# 26129          ideally natural  0.499438
# 26130      ambiguously natural  0.499438
# 26131            fully natural  0.499438
# 26132  disconcertingly natural  0.499438
# 26133      beautifully natural  0.499438
# 26134       absolutely natural  0.499438
# 26135       apparently natural  0.499438
# 26136           madly rational  0.499132
# 26137          artfully humble  0.499132
# 26138             really false  0.498732
# 26139        refreshingly cold  0.498611
# 26140           perfectly cold  0.498611
# 26141              simply wide  0.498611
# 26142          simply isolated  0.498611
# 26143               really low  0.498586
# 26144             really lower  0.498586
# 26145            roughly right  0.498586
# 26146             simply fresh  0.498105
# 26147     extraordinarily fast  0.497619
# 26148   extraordinarily faster  0.497619
# 26149          fiendishly fast  0.497619
# 26150         dangerously fast  0.497619
# 26151          extremely plain  0.497619
# 26152           instantly fast  0.497619
# 26153            wickedly fast  0.497619
# 26154        outrageously fast  0.497619
# 26155            terribly fast  0.497619
# ...                        ...       ...
# 30962         acceptably sharp  0.401548
# 30963     satisfactorily sharp  0.401548
# 30964          obviously sharp  0.401548
# 30965        marvelously sharp  0.401548
# 30966          curiously sharp  0.401548
# 30967          tolerably sharp  0.401548
# 30968         alarmingly sharp  0.401548
# 30969          generally older  0.401521
# 30970            brazenly fine  0.401250
# 30971          thoroughly fine  0.401250
# 30972       intrinsically fine  0.401250
# 30973          mockingly black  0.401196
# 30974              early black  0.401196
# 30975            exactly black  0.401196
# 30976        generally capable  0.401042
# 30977         insanely special  0.401042
# 30978           naturally keen  0.401042
# 30979        surprisingly grim  0.401042
# 30980      brilliantly capable  0.401042
# 30981        generally radical  0.401042
# 30982       fairly progressive  0.401042
# 30983     unmistakably genuine  0.400944
# 30984              only decent  0.400833
# 30985               really dry  0.400233
# 30986        incredibly bright  0.400231
# 30987      unbelievably bright  0.400231
# 30988            overly bright  0.400231
# 30989       excessively bright  0.400231
# 30990         generally closer  0.400014
# 30991          generally close  0.400014
#
# [4866 rows x 2 columns]

# %%
df[(df['diff'] > 0.5) & (df['diff'] < 0.6)][['pair', 'diff']]
# Out:
#                            pair      diff
# 19445              highly wrong  0.599851
# 19446               really poor  0.599792
# 19447       impressively bright  0.599769
# 19448   apparently disconnected  0.598958
# 19449       sanely conservative  0.598958
# 19450      unnecessarily savage  0.598958
# 19451                truly grim  0.598958
# 19452           really careless  0.598958
# 19453            extremely tall  0.598958
# 19454         really extraneous  0.598958
# 19455      highly contradictory  0.598958
# 19456           constantly just  0.598958
# 19457         really unthinking  0.598958
# 19458           overly precious  0.598958
# 19459       incredibly precious  0.598958
# 19460       really shortsighted  0.598958
# 19461      extraordinarily fine  0.598750
# 19462  extraordinarily tolerant  0.598750
# 19463                daily fine  0.598750
# 19464          dangerously fine  0.598750
# 19465          broadly tolerant  0.598750
# 19466             wickedly fine  0.598750
# 19467            entirely awful  0.598611
# 19468          completely awful  0.598611
# 19469           extremely awful  0.598611
# 19470          improbably sharp  0.598452
# 19471           highly unstable  0.597917
# 19472         morally offensive  0.597793
# 19473         unnaturally white  0.597656
# 19474            fully detached  0.597500
# ...                         ...       ...
# 24400           properly afraid  0.502604
# 24401     incredibly dependable  0.502604
# 24402         overly accessible  0.502604
# 24403     constantly accessible  0.502604
# 24404               really lean  0.502604
# 24405     incredibly accessible  0.502604
# 24406            really obscure  0.502083
# 24407    magnificently isolated  0.502083
# 24408            really erratic  0.501736
# 24409            really furious  0.501736
# 24410           perfectly fresh  0.501577
# 24411             plainly fresh  0.501577
# 24412            extremely sour  0.501389
# 24413          perfectly tender  0.501042
# 24414       thoughtfully tender  0.501042
# 24415     clearly unsympathetic  0.500972
# 24416            enjoyably wild  0.500960
# 24417             famously wild  0.500960
# 24418           absolutely wild  0.500960
# 24419           apparently wild  0.500960
# 24420                fully wild  0.500960
# 24421        unpredictably wild  0.500960
# 24422         comfortably happy  0.500868
# 24423               truly minor  0.500789
# 24424      artificially natural  0.500562
# 24425            extremely firm  0.500521
# 24426           completely firm  0.500521
# 24427             entirely firm  0.500521
# 24428           extremely small  0.500149
# 24429               oddly small  0.500149
#
# [4985 rows x 2 columns]

# %%
df[(df['diff'] > 0.3) & (df['diff'] < 0.4)][['pair', 'diff']]
# Out:
#                            pair      diff
# 30993               firmly flat  0.399901
# 30994         deliberately flat  0.399901
# 30995        actually offensive  0.399876
# 30996           genuinely sweet  0.399702
# 30997              doubly sweet  0.399702
# 30998           pleasantly open  0.399641
# 30999    reasonably indifferent  0.399493
# 31000           marginally sure  0.399333
# 31001          dramatically apt  0.399306
# 31002      furiously unbalanced  0.399306
# 31003           clearly crushed  0.399306
# 31004              clearly mere  0.399306
# 31005           clearly strange  0.399306
# 31006             clearly funny  0.399306
# 31007       strongly contingent  0.399306
# 31008  surprisingly unconcerned  0.399306
# 31009       surprisingly pallid  0.399306
# 31010  promiscuously unfaithful  0.399306
# 31011       surprisingly chilly  0.399306
# 31012             clearly tough  0.399140
# 31013           clearly tougher  0.399140
# 31014        necessarily bitter  0.399107
# 31015        unreasonably broad  0.398958
# 31016      monstrously insecure  0.398438
# 31017        fairly sympathetic  0.398438
# 31018       wildly incompatible  0.397971
# 31019       unbelievably smooth  0.397917
# 31020         incredibly smooth  0.397917
# 31021         invariably smooth  0.397917
# 31022           sharply smaller  0.397702
# ...                         ...       ...
# 38069            exactly social  0.302083
# 38070             only lukewarm  0.302083
# 38071                only tepid  0.302083
# 38072            only traumatic  0.302083
# 38073               only myopic  0.302083
# 38074               only unkind  0.302083
# 38075            only misguided  0.302083
# 38076              only riskier  0.302083
# 38077                only risky  0.302083
# 38078          only devastating  0.302083
# 38079                 only pure  0.301736
# 38080        unmistakably clear  0.301589
# 38081         immediately clear  0.301589
# 38082       cautiously positive  0.301290
# 38083           hardly positive  0.301290
# 38084       moderately positive  0.301290
# 38085             dismally dull  0.301280
# 38086           seemingly smart  0.301190
# 38087             totally smart  0.301190
# 38088        terrifically smart  0.301190
# 38089         obviously smarter  0.301190
# 38090           obviously smart  0.301190
# 38091           evidently smart  0.301190
# 38092           basically smart  0.301190
# 38093         wonderfully smart  0.301190
# 38094         essentially smart  0.301190
# 38095           actually colder  0.300695
# 38096             actually cold  0.300695
# 38097        desperately honest  0.300043
# 38098          lightly intimate  0.300000
#
# [7106 rows x 2 columns]
